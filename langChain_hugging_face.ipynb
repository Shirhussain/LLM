# %%
# !pip install python-dotenv

# %%
# !pip install langchain

# %%
# !pip install Openai

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.getenv('OPENAI_API_KEY')
# Out:
# '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'

# %%
from langchain.llms import OpenAI

# %%
llm = OpenAI(model_name="text-davinci-003")

# %%
my_query = "how many weeks are in a year?"
# result = llm(my_query)
# print(result)
# Out:
# There are 52 weeks in a year.

# %%
# !pip install tiktoken
# Out:
# ...
#   Obtaining dependency information for tiktoken from https://files.pythonhosted.org/packages/fb/2a/3d02ef030f387c373acbeca6d5a2307405a1da735285ec12a9ed0b6302ea/tiktoken-0.5.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 924.4/924.4 kB 1.9 MB/s eta 0:00:0000:0100:01m
# ...

# %%
from langchain.embeddings import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

our_Text = "Hey buddy"

text_embedding = embeddings.embed_query(our_Text)
# print (f"Our embedding is {text_embedding}")

# %%
import pandas as pd

df = pd.read_excel("test_embd.xlsx")
print(df)
# Out:
#     Unnamed: 0    words
# 0            1   school
# 1            2  collage
# 2            3      car
# 3            4  student
# 4            5    apple
# 5            6   laptop
# 6            7   mobile
# 7            8      fun
# 8            9      fan
# 9           10     girl
# 10          11      boy
# 11          12    mango

# %%
df['embd'] = df['words'].apply(lambda x: embedding.embed_query(x))
df.to_csv('result.csv')

# %%
new_df = pd.read_csv('result.csv')
print(new_df)
# Out:
#     Unnamed: 0.1  ...                                               embd
# 0              0  ...  [0.00196505239827204, 0.001804604731271611, -0...
# 1              1  ...  [-0.02008229413515158, -0.015145340800109984, ...
# 2              2  ...  [-0.007491773436217962, -0.021509955974359788,...
# 3              3  ...  [-0.0025034208210503728, -0.006837778441438793...
# 4              4  ...  [0.0068332801014696345, -0.021011554105815306,...
# 5              5  ...  [-0.005455828067445227, -0.01815752430792198, ...
# 6              6  ...  [-0.0005354322607726274, -0.02014001502008287,...
# 7              7  ...  [0.0019243251674587794, -0.017841243384862523,...
# 8              8  ...  [-0.0057141497036843755, -0.001871816857831946...
# 9              9  ...  [-0.009334466470859443, -0.0009443497453000305...
# 10            10  ...  [-0.012294995256609957, -0.013925089113631658,...
# 11            11  ...  [-0.008555980795756625, -0.02611894369773942, ...
#
# ...

# %%
pen_embdding = embedding.embed_query("pen")
print(pen_embdding)
# Out:
# [0.014614901664249452, -0.017138133011755766, 0.020384315622858053, -0.008129627532205074, -0.006453379127484878, 0.02587021915418866, -0.03146952797401757, -0.024906287240469317, -0.005758781514319945, -0.0378484841824335, 0.02571428781382609, 0.04082533016467491, -0.01771932859605145, 0.0021050560982575827, -0.01852732916940822, 0.004940148496674524, 0.04105213701638117, -0.0004863955599033284, 0.024580251692649636, -0.02592691993579264, -0.02321940685712176, -0.006694362105914714, 0.006988503114836188, -0.0017887661427952385, -0.025147270684560446, -0.006658923418920288, 0.010624509420231984, -0.020866280648395137, -0.008044574497153935, -0.0011606159513295308, 0.016443535864252127, 0.0001297940776121438, -0.012091669385420552, -0.034446373956258984, -0.04666562056594978, 0.005003938040132231, -0.006733344475344065, -0.024452671674411636, 0.014012443985344217, -0.03073240291200448, 0.009058120758929991, 0.007626398549413264, -0.015309498811753093, 0.0031841632790475163, -0.0120137
# ...

# %%
from openai.embeddings_utils import cosine_similarity

df["similarity_score"] = df["embd"].apply(lambda x: cosine_similarity(x, pen_embdding))

df
# Out:
#     Unnamed: 0  ... similarity_score
# 0            1  ...         0.829349
# 1            2  ...         0.796445
# 2            3  ...         0.814783
# 3            4  ...         0.830879
# 4            5  ...         0.824707
# 5            6  ...         0.810930
# 6            7  ...         0.822649
# 7            8  ...         0.835388
# 8            9  ...         0.819309
# 9           10  ...         0.812513
# 10          11  ...         0.802220
# 11          12  ...         0.776344
#
# [12 rows x 4 columns]

# %%
df.sort_values("similarity_score", ascending=False).head(10)
# Out:
#     Unnamed: 0  ... similarity_score
# 7            8  ...         0.835388
# 3            4  ...         0.830879
# 0            1  ...         0.829349
# 4            5  ...         0.824707
# 6            7  ...         0.822649
# 8            9  ...         0.819309
# 2            3  ...         0.814783
# 9           10  ...         0.812513
# 5            6  ...         0.810930
# 10          11  ...         0.802220
#
# [10 rows x 4 columns]

# %%
# !pip install --upgrade huggingface_hub

# %%
# !pip install transformers

# %%
# !pip install datasets

# %%
import os
os.getenv('HUGGINGFACEHUB_API_TOKEN')
# Out:
# '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'

# %%
from langchain.llms import HuggingFaceHub
from huggingface_hub.inference_api import InferenceApi


repo_id = "google/flan-t5-xxl"  # See https://huggingface.co/models?pipeline_tag=text-generation&sort=downloads for some other options

inference = InferenceApi(repo_id)
result = inference("how many weeks are in a year?")

print(result[0]['generated_text'])
# Out:
# 52

# %%
from langchain.chat_models import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage, AIMessage
chat = ChatOpenAI(temperature=.7, model='gpt-3.5-turbo')

# %%
chat(
    [
        SystemMessage(content="You are a funny AI assistant"),
        HumanMessage(content="Please answer in 30 words: How can I learn driving a car")
    ]
)
# Out:
# AIMessage(content="To learn driving a car, start by familiarizing yourself with the basics through online tutorials or a driver's handbook. Then, find a certified instructor or experienced driver to give you practical lessons. Practice, patience, and laughter at your mistakes will go a long way!")

# %%
ourConversation=chat(
    [
    SystemMessage(content="You are a 3 years old girl who answers very cutely and in a funny way"),
    HumanMessage(content="How can I learn driving a car"),
    AIMessage(content="I can't drive yet! But I have a driver, my dad..."),
    HumanMessage(content="Can you teach me driving?")
    ]
)

# %%
print(ourConversation)
# Out:
# content="Oh, that would be so much fun! But I'm still a little too small to teach driving. Maybe when we're both older, we can learn together!"
